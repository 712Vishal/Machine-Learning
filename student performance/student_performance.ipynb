# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/visha/Desktop/GROW TECH/python/Machine learning/dataset/Student_Performance.csv')

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.describe().T
# Out:
#                                     count     mean        std   min   25%  \
# Hours Studied                     10000.0   4.9929   2.589309   1.0   3.0
# Previous Scores                   10000.0  69.4457  17.343152  40.0  54.0
# Sleep Hours                       10000.0   6.5306   1.695863   4.0   5.0
# Sample Question Papers Practiced  10000.0   4.5833   2.867348   0.0   2.0
# Performance Index                 10000.0  55.2248  19.212558  10.0  40.0
#
#                                    50%   75%    max
# Hours Studied                      5.0   7.0    9.0
# Previous Scores                   69.0  85.0   99.0
# Sleep Hours                        7.0   8.0    9.0
# Sample Question Papers Practiced   5.0   7.0    9.0
# Performance Index                 55.0  71.0  100.0

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %% [markdown]
# # ===============================================================================================================

# %% [markdown]
# # data visualization

# %%
sns.countplot(df["Extracurricular Activities"])
# Out:
# <Axes: xlabel='count', ylabel='Extracurricular Activities'>

# %%
sns.countplot(df,x="Performance Index",hue='Extracurricular Activities')
# Out:
# <Axes: xlabel='Performance Index', ylabel='count'>

# %%
sns.histplot(df,x="Performance Index",hue='Extracurricular Activities')
# Out:
# <Axes: xlabel='Performance Index', ylabel='Count'>

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10, 5))
sns.heatmap(corr, annot=True, cmap="coolwarm", square=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.boxplot(x="Extracurricular Activities", y="Performance Index", data=df, )
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
sns.scatterplot(x="Hours Studied", y="Performance Index", data=df, alpha=0.5, )

plt.show()

# %% [markdown]
# # feature extration

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()
df['Extracurricular Activities']=lab_enc.fit_transform(df['Extracurricular Activities'])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
# x=df[["Hours Studied","Previous Scores","Sleep Hours","Sample Question Papers Practiced"]]
# x

# %%
# y=df[['Performance Index']]
# y

# %%
# split into independent and dependent variable 
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
# another method

# x=df.drop('Performance Index',axis=1)
# y=df['Performance Index']

# %% [markdown]
# # feature encoding

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %% [markdown]
# # split into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
(x_train.shape,x_test.shape)
# Out:
# ((7000, 5), (3000, 5))

# %%
(y_train.shape,y_test.shape)
# Out:
# ((7000,), (3000,))

# %% [markdown]
# # data normalization

# %%
from sklearn.preprocessing import StandardScaler
s_scale=StandardScaler()

x_train_scaled=s_scale.fit(x_train)
x_test_scaled=s_scale.transform(x_test)

# %% [markdown]
# # model training

# %%
from sklearn.linear_model import LinearRegression

lin_model=LinearRegression()
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin_model.predict(x_test)
y_pred
# Out:
# array([45.69328476, 55.9236519 , 45.519203  , ..., 55.87633202,
#        73.72691363, 39.64503778])

# %%
y_test
# Out:
# 8908    50.0
# 8789    59.0
# 715     50.0
# 5454    71.0
# 3440    82.0
#         ...
# 2075    36.0
# 8241    74.0
# 6719    55.0
# 1584    75.0
# 2458    39.0
# Name: Performance Index, Length: 3000, dtype: float64

# %%
# check model accuracy
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 98.87529134722067

# %%
# training accuracy
lin_model.score(x_train,y_train)
# Out:
# 0.9887499795130896

# %%
# testing accuracy # training accuracy # check model accuracy
lin_model.score(x_test,y_test)
# Out:
# 0.9887529134722067
